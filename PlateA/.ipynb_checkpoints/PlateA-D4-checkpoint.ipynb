# %%
'''
Description
Author: David Brin
Date created 9/23/24

This notebook uses "A_LFP_analysis_functions.py" for all imports and functions necessary for analysis. 
This notebook shows the raw and fitted power spectra from preprocessed LFP recordings, spatial spike activity along with active windows,
and the raw and fitted spectra of active windows, along with the distribution and variation of aperiodic and peak parameters. 
'''
# Out:
# '\nDescription\nAuthor: David Brin\nDate created 9/23/24\n\nThis notebook uses "A_LFP_analysis_functions.py" for all imports and functions necessary for analysis. \nThis notebook shows the raw and fitted power spectra from preprocessed LFP recordings, spatial spike activity along with active windows,\nand the raw and fitted spectra of active windows, along with the distribution and variation of aperiodic and peak parameters. \n'

# %%
# %run "./A_LFP_analysis_functions.py"
# Out:
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:54: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   from fooof import FOOOF

# %%
lfp_data = load_lfp(r"C:\Users\david\Documents\Voytek Research\LFP_psych_proj\PlateA\PlateA_D1\poststim_lfp_data.h5")
spike_times = load_spikes(r"C:\Users\david\Documents\Voytek Research\LFP_psych_proj\PlateA\PlateA_D1\spike_data.mat")
# Out:
# (2, 3, 60325)
# dict_keys(['__header__', '__version__', '__globals__', 'None', 'spike_times', 'spike_waveforms', '__function_workspace__'])

# %% [markdown]
# ## Full power spectra

# %%
 plot_all_pspectra(lfp_data)

# %%
fooof_all_pspectra(lfp_data, fs_ds = 100, fmode = "fixed")
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4942, 2.7682
#
#                                        1 peaks were found:
#                                 CF:  21.20, PW:  0.798, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9578
#                                     Error of the fit is 0.1885
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3581, 2.7270
#
#                                        1 peaks were found:
#                                 CF:  21.78, PW:  0.756, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9614
#                                     Error of the fit is 0.1755
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4162, 2.8325
#
#                                        2 peaks were found:
#                                 CF:  19.64, PW:  0.741, BW: 12.00
#                                 CF:  37.45, PW:  0.396, BW:  9.68
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9710
#                                     Error of the fit is 0.1428
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3770, 2.7144
#
#                                        1 peaks were found:
#                                 CF:  20.80, PW:  0.758, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9623
#                                     Error of the fit is 0.1769
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4355, 2.7564
#
#                                        1 peaks were found:
#                                 CF:  21.24, PW:  0.788, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9610
#                                     Error of the fit is 0.1779
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4395, 2.7574
#
#                                        1 peaks were found:
#                                 CF:  21.23, PW:  0.768, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9609
#                                     Error of the fit is 0.1774
#
# ==================================================================================================

# %% [markdown]
# ## Spike Activity

# %% [markdown]
# ### Spacial activity

# %%
spike_spacial_visualization(spike_times)

# %%
 spike_threshold_vis(spike_times)

# %% [markdown]
# ### Temporal activity

# %%
find_and_plot_active_spike_windows(spike_times, 100)

# %%
spike_times_by_well = spikes_by_well(spike_times)
binary_activity = plot_num_spikes_hist(spike_times_by_well, 100, num_windows = 6, threshold = 50) 
#plots histogram of windows above 50 spikes and creates binary_activity

# %% [markdown]
# ## Windowed analysis

# %%
fooof_wind_thresh(binary_activity, lfp_data, 100, fmode = "fixed")
# Out:
# fitting all 100s active windows per well
# fitting well 0,0 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4807, 2.7820
#
#                                        1 peaks were found:
#                                 CF:  21.27, PW:  0.864, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9552
#                                     Error of the fit is 0.1955
#
# ==================================================================================================
# fitting well 0,0 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.2886, 2.6728
#
#                                        2 peaks were found:
#                                 CF:  13.98, PW:  0.616, BW: 12.00
#                                 CF:  28.72, PW:  0.542, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9859
#                                     Error of the fit is 0.0870
#
# ==================================================================================================
# fitting well 0,0 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4807, 2.7766
#
#                                        1 peaks were found:
#                                 CF:  21.33, PW:  0.852, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9533
#                                     Error of the fit is 0.1916
#
# ==================================================================================================
# fitting well 0,0 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4763, 2.7659
#
#                                        1 peaks were found:
#                                 CF:  21.38, PW:  0.836, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9554
#                                     Error of the fit is 0.1940
#
# ==================================================================================================
# fitting well 0,0 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4734, 2.7591
#
#                                        1 peaks were found:
#                                 CF:  21.25, PW:  0.832, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9552
#                                     Error of the fit is 0.1838
#
# ==================================================================================================
# fitting well 0,0 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.5441, 2.8344
#
#                                        1 peaks were found:
#                                 CF:  22.07, PW:  0.871, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9488
#                                     Error of the fit is 0.2105
#
# ==================================================================================================
# fitting well 1,0 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.2138, 2.6780
#
#                                        2 peaks were found:
#                                 CF:  14.50, PW:  0.618, BW: 12.00
#                                 CF:  29.63, PW:  0.607, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9848
#                                     Error of the fit is 0.0955
#
# ==================================================================================================
# fitting well 1,0 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3543, 2.7069
#
#                                        1 peaks were found:
#                                 CF:  19.83, PW:  0.768, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9591
#                                     Error of the fit is 0.1883
#
# ==================================================================================================
# fitting well 1,0 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3412, 2.6942
#
#                                        1 peaks were found:
#                                 CF:  20.82, PW:  0.756, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9635
#                                     Error of the fit is 0.1696
#
# ==================================================================================================
# fitting well 1,0 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.2656, 2.7025
#
#                                        2 peaks were found:
#                                 CF:  14.75, PW:  0.593, BW: 12.00
#                                 CF:  29.04, PW:  0.545, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9856
#                                     Error of the fit is 0.0890
#
# ==================================================================================================
# fitting well 1,0 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4354, 2.7661
#
#                                        1 peaks were found:
#                                 CF:  22.09, PW:  0.766, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9628
#                                     Error of the fit is 0.1757
#
# ==================================================================================================
# fitting well 1,0 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4746, 2.8003
#
#                                        1 peaks were found:
#                                 CF:  21.83, PW:  0.768, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9586
#                                     Error of the fit is 0.1855
#
# ==================================================================================================
# fitting well 1,1 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4383, 2.7567
#
#                                        1 peaks were found:
#                                 CF:  21.01, PW:  0.755, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9605
#                                     Error of the fit is 0.1733
#
# ==================================================================================================
# fitting well 1,1 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.2275, 2.6913
#
#                                        2 peaks were found:
#                                 CF:  14.52, PW:  0.643, BW: 12.00
#                                 CF:  29.83, PW:  0.591, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9870
#                                     Error of the fit is 0.0853
#
# ==================================================================================================
# fitting well 1,1 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4131, 2.7350
#
#                                        1 peaks were found:
#                                 CF:  20.78, PW:  0.793, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9559
#                                     Error of the fit is 0.1868
#
# ==================================================================================================
# fitting well 1,1 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3637, 2.7108
#
#                                        1 peaks were found:
#                                 CF:  20.60, PW:  0.817, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9553
#                                     Error of the fit is 0.1879
#
# ==================================================================================================
# fitting well 1,1 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.2258, 2.6916
#
#                                        2 peaks were found:
#                                 CF:  14.79, PW:  0.680, BW: 12.00
#                                 CF:  29.59, PW:  0.559, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9833
#                                     Error of the fit is 0.0980
#
# ==================================================================================================
# fitting well 1,1 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.2388, 2.6843
#
#                                        2 peaks were found:
#                                 CF:  14.62, PW:  0.621, BW: 12.00
#                                 CF:  29.51, PW:  0.564, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9827
#                                     Error of the fit is 0.0995
#
# ==================================================================================================

# %%
ndsp_wind_thresh(binary_activity, lfp_data, 100)
# Out:
# fitting all 100s active windows per well
# fitting well 0,0 0:100
# fitting well 0,0 100:200
# fitting well 0,0 200:300
# fitting well 0,0 300:400
# fitting well 0,0 400:500
# fitting well 0,0 500:600
# fitting well 1,0 0:100
# fitting well 1,0 100:200
# fitting well 1,0 200:300
# fitting well 1,0 300:400
# fitting well 1,0 400:500
# fitting well 1,0 500:600
# fitting well 1,1 0:100
# fitting well 1,1 100:200
# fitting well 1,1 200:300
# fitting well 1,1 300:400
# fitting well 1,1 400:500
# fitting well 1,1 500:600

# %% [markdown]
# ## Variation of FoooF Parameters

# %%
fm_array = set_fm_array(lfp_data)
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.

# %%
param_heatmap(fm_array)

# %%
dose_grid = np.array([
    ['eGFP', 'eGFP', 'eGFP'],
    ['CheRiff', 'CheRiff', 'CheRiff']])

# %%
plot_variability(fm_array, dose_grid)
# Out:
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:652: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=values, palette="viridis")
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:652: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=values, palette="viridis")

# %%
plot_aperiodic_boxplot(fm_array,  dose_grid)

# %%
 plot_peak_boxplot(fm_array,  dose_grid)
