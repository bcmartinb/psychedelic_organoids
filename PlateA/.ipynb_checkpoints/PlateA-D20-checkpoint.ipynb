# %%
'''
Description
Author: David Brin
Date created 9/23/24

This notebook uses "A_LFP_analysis_functions.py" for all imports and functions necessary for analysis. 
This notebook shows the raw and fitted power spectra from preprocessed LFP recordings, spatial spike activity along with active windows,
and the raw and fitted spectra of active windows, along with the distribution and variation of aperiodic and peak parameters. 
'''
# Out:
# '\nDescription\nAuthor: David Brin\nDate created 9/23/24\n\nThis notebook uses "A_LFP_analysis_functions.py" for all imports and functions necessary for analysis. \nThis notebook shows the raw and fitted power spectra from preprocessed LFP recordings, spatial spike activity along with active windows,\nand the raw and fitted spectra of active windows, along with the distribution and variation of aperiodic and peak parameters. \n'

# %%
# %run "./A_LFP_analysis_functions.py"
# Out:
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:54: DeprecationWarning:
# The `fooof` package is being deprecated and replaced by the `specparam` (spectral parameterization) package.
# This version of `fooof` (1.1) is fully functional, but will not be further updated.
# New projects are recommended to update to using `specparam` (see Changelog for details).
#   from fooof import FOOOF

# %%
lfp_data = load_lfp(r"C:\Users\david\Documents\Voytek Research\LFP_psych_proj\PlateA\PlateA_D18\d18_lfp_data.h5")
spike_times = load_spikes(r"C:\Users\david\Documents\Voytek Research\LFP_psych_proj\PlateA\PlateA_D18\spike_data_10min.mat")
# Out:
# (2, 3, 77850)
# dict_keys(['__header__', '__version__', '__globals__', 'None', 'spike_times', 'spike_waveforms', '__function_workspace__'])

# %% [markdown]
# ## Full power spectra

# %%
 plot_all_pspectra(lfp_data)

# %%
fooof_all_pspectra(lfp_data, fs_ds = 100, fmode = "fixed")
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4612, 2.7456
#
#                                        1 peaks were found:
#                                 CF:  20.96, PW:  0.800, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9570
#                                     Error of the fit is 0.1886
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3783, 2.7284
#
#                                        1 peaks were found:
#                                 CF:  21.78, PW:  0.736, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9636
#                                     Error of the fit is 0.1701
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3997, 2.8036
#
#                                        2 peaks were found:
#                                 CF:  19.79, PW:  0.724, BW: 12.00
#                                 CF:  37.45, PW:  0.355, BW:  9.34
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9724
#                                     Error of the fit is 0.1421
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3699, 2.7012
#
#                                        1 peaks were found:
#                                 CF:  21.17, PW:  0.748, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9611
#                                     Error of the fit is 0.1775
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4187, 2.7411
#
#                                        1 peaks were found:
#                                 CF:  21.36, PW:  0.768, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9616
#                                     Error of the fit is 0.1735
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4214, 2.7402
#
#                                        1 peaks were found:
#                                 CF:  21.35, PW:  0.776, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9590
#                                     Error of the fit is 0.1833
#
# ==================================================================================================

# %% [markdown]
# ## Spike Activity

# %% [markdown]
# ### Spacial activity

# %%
spike_spacial_visualization(spike_times)

# %%
 spike_threshold_vis(spike_times)

# %% [markdown]
# ### Temporal activity

# %%
find_and_plot_active_spike_windows(spike_times, 100)

# %%
spike_times_by_well = spikes_by_well(spike_times)
binary_activity = plot_num_spikes_hist(spike_times_by_well, 100, num_windows = 6, threshold = 50) 
#plots histogram of windows above 50 spikes and creates binary_activity

# %% [markdown]
# ## Windowed analysis

# %%
fooof_wind_thresh(binary_activity, lfp_data, 100, fmode = "fixed")
# Out:
# fitting all 100s active windows per well
# fitting well 0,0 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4767, 2.7592
#
#                                        1 peaks were found:
#                                 CF:  21.20, PW:  0.775, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9568
#                                     Error of the fit is 0.1794
#
# ==================================================================================================
# fitting well 0,0 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.2198, 2.6634
#
#                                        2 peaks were found:
#                                 CF:  14.52, PW:  0.676, BW: 12.00
#                                 CF:  29.69, PW:  0.633, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9822
#                                     Error of the fit is 0.0996
#
# ==================================================================================================
# fitting well 0,0 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4957, 2.7620
#
#                                        1 peaks were found:
#                                 CF:  21.24, PW:  0.773, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9625
#                                     Error of the fit is 0.1688
#
# ==================================================================================================
# fitting well 0,0 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3038, 2.7109
#
#                                        2 peaks were found:
#                                 CF:  14.22, PW:  0.611, BW: 12.00
#                                 CF:  29.17, PW:  0.621, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9863
#                                     Error of the fit is 0.0901
#
# ==================================================================================================
# fitting well 0,0 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3784, 2.7724
#
#                                        2 peaks were found:
#                                 CF:  15.74, PW:  0.662, BW: 12.00
#                                 CF:  30.10, PW:  0.579, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9831
#                                     Error of the fit is 0.1019
#
# ==================================================================================================
# fitting well 0,0 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4492, 2.7483
#
#                                        1 peaks were found:
#                                 CF:  20.75, PW:  0.828, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9537
#                                     Error of the fit is 0.1968
#
# ==================================================================================================
# fitting well 1,0 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4014, 2.7337
#
#                                        1 peaks were found:
#                                 CF:  22.17, PW:  0.732, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9547
#                                     Error of the fit is 0.1931
#
# ==================================================================================================
# fitting well 1,0 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3867, 2.7104
#
#                                        1 peaks were found:
#                                 CF:  21.18, PW:  0.756, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9563
#                                     Error of the fit is 0.1814
#
# ==================================================================================================
# fitting well 1,0 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3693, 2.7092
#
#                                        1 peaks were found:
#                                 CF:  20.91, PW:  0.785, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9597
#                                     Error of the fit is 0.1780
#
# ==================================================================================================
# fitting well 1,0 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3284, 2.6941
#
#                                        1 peaks were found:
#                                 CF:  20.46, PW:  0.781, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9629
#                                     Error of the fit is 0.1688
#
# ==================================================================================================
# fitting well 1,0 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3950, 2.7363
#
#                                        1 peaks were found:
#                                 CF:  21.71, PW:  0.798, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9523
#                                     Error of the fit is 0.1929
#
# ==================================================================================================
# fitting well 1,0 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3348, 2.6831
#
#                                        1 peaks were found:
#                                 CF:  20.27, PW:  0.727, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9605
#                                     Error of the fit is 0.1785
#
# ==================================================================================================
# fitting well 1,1 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3891, 2.7330
#
#                                        1 peaks were found:
#                                 CF:  21.15, PW:  0.811, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9590
#                                     Error of the fit is 0.1809
#
# ==================================================================================================
# fitting well 1,1 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3793, 2.7266
#
#                                        1 peaks were found:
#                                 CF:  21.08, PW:  0.760, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9597
#                                     Error of the fit is 0.1771
#
# ==================================================================================================
# fitting well 1,1 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4660, 2.7727
#
#                                        1 peaks were found:
#                                 CF:  21.73, PW:  0.768, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9566
#                                     Error of the fit is 0.1869
#
# ==================================================================================================
# fitting well 1,1 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4414, 2.7615
#
#                                        1 peaks were found:
#                                 CF:  21.25, PW:  0.762, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9589
#                                     Error of the fit is 0.1831
#
# ==================================================================================================
# fitting well 1,1 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4279, 2.7325
#
#                                        1 peaks were found:
#                                 CF:  21.02, PW:  0.750, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9627
#                                     Error of the fit is 0.1751
#
# ==================================================================================================
# fitting well 1,1 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4214, 2.7542
#
#                                        1 peaks were found:
#                                 CF:  21.59, PW:  0.802, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9518
#                                     Error of the fit is 0.1968
#
# ==================================================================================================

# %%
ndsp_wind_thresh(binary_activity, lfp_data, 100)
# Out:
# fitting all 100s active windows per well
# fitting well 0,0 0:100
# fitting well 0,0 100:200
# fitting well 0,0 200:300
# fitting well 0,0 300:400
# fitting well 0,0 400:500
# fitting well 0,0 500:600
# fitting well 1,0 0:100
# fitting well 1,0 100:200
# fitting well 1,0 200:300
# fitting well 1,0 300:400
# fitting well 1,0 400:500
# fitting well 1,0 500:600
# fitting well 1,1 0:100
# fitting well 1,1 100:200
# fitting well 1,1 200:300
# fitting well 1,1 300:400
# fitting well 1,1 400:500
# fitting well 1,1 500:600

# %% [markdown]
# ## Variation of FoooF Parameters

# %%
fm_array = set_fm_array(lfp_data)
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.

# %%
param_heatmap(fm_array)

# %%
dose_grid = np.array([
    ['eGFP', 'eGFP', 'eGFP'],
    ['CheRiff', 'CheRiff', 'CheRiff']])

# %%
plot_variability(fm_array, dose_grid)
# Out:
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:652: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=values, palette="viridis")
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:652: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=values, palette="viridis")

# %%
plot_aperiodic_boxplot(fm_array,  dose_grid)

# %%
 plot_peak_boxplot(fm_array,  dose_grid)
