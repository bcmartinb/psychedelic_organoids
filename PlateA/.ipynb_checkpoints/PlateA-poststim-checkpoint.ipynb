# %%
'''
Description
Author: David Brin
Date created 9/19/24

This notebook uses "General_LFP_analysis_functions.py" for all imports and functions necessary for analysis. 
This notebook shows the raw and fitted power spectra from preprocessed LFP recordings, spatial spike activity along with active windows,
and the raw and fitted spectra of active windows, along with the distribution and variation of aperiodic and peak parameters. 
'''
# Out:
# '\nDescription\nAuthor: David Brin\nDate created 9/19/24\n\nThis notebook uses "General_LFP_analysis_functions.py" for all imports and functions necessary for analysis. \nThis notebook shows the raw and fitted power spectra from preprocessed LFP recordings, spatial spike activity along with active windows,\nand the raw and fitted spectra of active windows, along with the distribution and variation of aperiodic and peak parameters. \n'

# %%
# %run "./A_LFP_analysis_functions.py"

# %%
lfp_data = load_lfp(r"C:\Users\david\Documents\Voytek Research\LFP_psych_proj\PlateA\PlateA_D0\poststim_lfp_data.h5")
spike_times = load_spikes(r"C:\Users\david\Documents\Voytek Research\LFP_psych_proj\PlateA\PlateA_D0\poststim_spike_data.mat")
# Out:
# (2, 3, 86500)
# dict_keys(['__header__', '__version__', '__globals__', 'None', 'spike_times', 'spike_waveforms', '__function_workspace__'])

# %% [markdown]
# ## Full power spectra

# %%
 plot_all_pspectra(lfp_data)

# %% [markdown]
# ## Spike Activity

# %% [markdown]
# ### Spacial activity

# %%
spike_spacial_visualization(spike_times)

# %%
 spike_threshold_vis(spike_times)

# %% [markdown]
# ### Temporal activity

# %%
find_and_plot_active_spike_windows(spike_times, 100)

# %%
spike_times_by_well = spikes_by_well(spike_times)
binary_activity = plot_num_spikes_hist(spike_times_by_well, 100, num_windows = 6, threshold = 50) 
#plots histogram of windows above 50 spikes and creates binary_activity

# %% [markdown]
# ## Windowed analysis

# %%
fooof_wind_thresh(binary_activity, lfp_data, 100, fmode = "fixed")
# Out:
# fitting all 100s active windows per well
# fitting well 0,0 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.5444, 2.8096
#
#                                        1 peaks were found:
#                                 CF:  21.67, PW:  0.795, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9539
#                                     Error of the fit is 0.1941
#
# ==================================================================================================
# fitting well 0,0 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.5159, 2.8046
#
#                                        1 peaks were found:
#                                 CF:  22.09, PW:  0.863, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9527
#                                     Error of the fit is 0.2000
#
# ==================================================================================================
# fitting well 0,0 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4524, 2.7347
#
#                                        1 peaks were found:
#                                 CF:  20.36, PW:  0.791, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9535
#                                     Error of the fit is 0.1911
#
# ==================================================================================================
# fitting well 0,0 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3869, 2.7110
#
#                                        1 peaks were found:
#                                 CF:  20.50, PW:  0.864, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9513
#                                     Error of the fit is 0.2016
#
# ==================================================================================================
# fitting well 0,0 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4448, 2.7377
#
#                                        1 peaks were found:
#                                 CF:  20.32, PW:  0.840, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9527
#                                     Error of the fit is 0.1981
#
# ==================================================================================================
# fitting well 0,0 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4633, 2.7382
#
#                                        1 peaks were found:
#                                 CF:  20.92, PW:  0.772, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9574
#                                     Error of the fit is 0.1803
#
# ==================================================================================================
# fitting well 1,0 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3913, 2.7055
#
#                                        1 peaks were found:
#                                 CF:  21.62, PW:  0.714, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9647
#                                     Error of the fit is 0.1634
#
# ==================================================================================================
# fitting well 1,0 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3865, 2.7161
#
#                                        1 peaks were found:
#                                 CF:  21.36, PW:  0.723, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9579
#                                     Error of the fit is 0.1801
#
# ==================================================================================================
# fitting well 1,0 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.2259, 2.6960
#
#                                        2 peaks were found:
#                                 CF:  14.05, PW:  0.586, BW: 11.84
#                                 CF:  29.59, PW:  0.607, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9832
#                                     Error of the fit is 0.1050
#
# ==================================================================================================
# fitting well 1,0 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3896, 2.7370
#
#                                        1 peaks were found:
#                                 CF:  21.67, PW:  0.839, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9524
#                                     Error of the fit is 0.1920
#
# ==================================================================================================
# fitting well 1,0 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3614, 2.6942
#
#                                        1 peaks were found:
#                                 CF:  20.61, PW:  0.715, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9657
#                                     Error of the fit is 0.1724
#
# ==================================================================================================
# fitting well 1,0 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4520, 2.7652
#
#                                        1 peaks were found:
#                                 CF:  21.41, PW:  0.707, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9639
#                                     Error of the fit is 0.1693
#
# ==================================================================================================
# fitting well 1,1 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3830, 2.7139
#
#                                        1 peaks were found:
#                                 CF:  20.34, PW:  0.806, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9555
#                                     Error of the fit is 0.1866
#
# ==================================================================================================
# fitting well 1,1 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3795, 2.7043
#
#                                        1 peaks were found:
#                                 CF:  19.41, PW:  0.727, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9621
#                                     Error of the fit is 0.1730
#
# ==================================================================================================
# fitting well 1,1 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4906, 2.7977
#
#                                        1 peaks were found:
#                                 CF:  21.77, PW:  0.771, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9547
#                                     Error of the fit is 0.1954
#
# ==================================================================================================
# fitting well 1,1 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4606, 2.7885
#
#                                        1 peaks were found:
#                                 CF:  21.70, PW:  0.805, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9534
#                                     Error of the fit is 0.1963
#
# ==================================================================================================
# fitting well 1,1 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4014, 2.7306
#
#                                        1 peaks were found:
#                                 CF:  21.13, PW:  0.799, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9547
#                                     Error of the fit is 0.1923
#
# ==================================================================================================
# fitting well 1,1 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3033, 2.7344
#
#                                        2 peaks were found:
#                                 CF:  14.63, PW:  0.598, BW: 12.00
#                                 CF:  29.31, PW:  0.555, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9828
#                                     Error of the fit is 0.1002
#
# ==================================================================================================

# %%
ndsp_wind_thresh(binary_activity, lfp_data, 100)
# Out:
# fitting all 100s active windows per well
# fitting well 0,0 0:100
# fitting well 0,0 100:200
# fitting well 0,0 200:300
# fitting well 0,0 300:400
# fitting well 0,0 400:500
# fitting well 0,0 500:600
# fitting well 1,0 0:100
# fitting well 1,0 100:200
# fitting well 1,0 200:300
# fitting well 1,0 300:400
# fitting well 1,0 400:500
# fitting well 1,0 500:600
# fitting well 1,1 0:100
# fitting well 1,1 100:200
# fitting well 1,1 200:300
# fitting well 1,1 300:400
# fitting well 1,1 400:500
# fitting well 1,1 500:600

# %% [markdown]
# ## Variation of FoooF Parameters

# %%
fm_array = set_fm_array(lfp_data)
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.

# %%
param_heatmap(fm_array)

# %%
dose_grid = np.array([
    ['eGFP', 'eGFP', 'eGFP'],
    ['CheRiff', 'CheRiff', 'CheRiff']])

# %%
plot_variability(fm_array, dose_grid)
# Out:
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:633: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=values, palette="viridis")
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:633: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=values, palette="viridis")

# %%
plot_aperiodic_boxplot(fm_array,  dose_grid)

# %%
 plot_peak_boxplot(fm_array,  dose_grid)
