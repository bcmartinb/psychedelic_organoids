# %%
'''
Description
Author: David Brin
Date created 9/19/24

This notebook uses "General_LFP_analysis_functions.py" for all imports and functions necessary for analysis. 
This notebook shows the raw and fitted power spectra from preprocessed LFP recordings, spatial spike activity along with active windows,
and the raw and fitted spectra of active windows, along with the distribution and variation of aperiodic and peak parameters. 
'''
# Out:
# '\nDescription\nAuthor: David Brin\nDate created 9/19/24\n\nThis notebook uses "General_LFP_analysis_functions.py" for all imports and functions necessary for analysis. \nThis notebook shows the raw and fitted power spectra from preprocessed LFP recordings, spatial spike activity along with active windows,\nand the raw and fitted spectra of active windows, along with the distribution and variation of aperiodic and peak parameters. \n'

# %%
# %run "./A_LFP_analysis_functions.py"

# %%
lfp_data = load_lfp(r"C:\Users\david\Documents\Voytek Research\LFP_psych_proj\PlateA\PlateA_D0\prestim_lfp_data.h5")
spike_times = load_spikes(r"C:\Users\david\Documents\Voytek Research\LFP_psych_proj\PlateA\PlateA_D0\prestim_spike_data.mat")
# Out:
# (2, 3, 61475)
# dict_keys(['__header__', '__version__', '__globals__', 'None', 'spike_times', 'spike_waveforms', '__function_workspace__'])

# %% [markdown]
# ## Full power spectra

# %%
 plot_all_pspectra(lfp_data)

# %%
fooof_all_pspectra(lfp_data, fs_ds = 100, fmode = "fixed")
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.5015, 2.4052
#
#                                        1 peaks were found:
#                                 CF:  22.27, PW:  0.933, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9284
#                                     Error of the fit is 0.2146
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.5970, 2.4736
#
#                                        1 peaks were found:
#                                 CF:  22.39, PW:  0.864, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9390
#                                     Error of the fit is 0.2000
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4682, 2.3490
#
#                                        1 peaks were found:
#                                 CF:  23.99, PW:  0.953, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9216
#                                     Error of the fit is 0.2165
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.5372, 2.5156
#
#                                        2 peaks were found:
#                                 CF:  20.27, PW:  0.853, BW: 12.00
#                                 CF:  37.45, PW:  0.486, BW:  9.20
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9565
#                                     Error of the fit is 0.1558
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.6199, 2.4640
#
#                                        1 peaks were found:
#                                 CF:  22.15, PW:  0.905, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9315
#                                     Error of the fit is 0.2151
#
# ==================================================================================================
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3794, 2.4017
#
#                                        2 peaks were found:
#                                 CF:  15.69, PW:  0.732, BW: 12.00
#                                 CF:  30.59, PW:  0.691, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9796
#                                     Error of the fit is 0.0892
#
# ==================================================================================================

# %% [markdown]
# ## Spike Activity

# %% [markdown]
# ### Spacial activity

# %%
spike_spacial_visualization(spike_times)

# %%
 spike_threshold_vis(spike_times)

# %% [markdown]
# ### Temporal activity

# %%
find_and_plot_active_spike_windows(spike_times, 100)

# %%
spike_times_by_well = spikes_by_well(spike_times)
binary_activity = plot_num_spikes_hist(spike_times_by_well, 100, num_windows = 6, threshold = 50) 
#plots histogram of windows above 50 spikes and creates binary_activity

# %% [markdown]
# ## Windowed analysis

# %%
fooof_wind_thresh(binary_activity, lfp_data, 100, fmode = "fixed")
# Out:
# fitting all 100s active windows per well
# fitting well 1,0 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3463, 2.4179
#
#                                        3 peaks were found:
#                                 CF:  14.46, PW:  0.653, BW: 12.00
#                                 CF:  28.41, PW:  0.730, BW: 12.00
#                                 CF:  39.19, PW:  0.475, BW:  4.73
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9791
#                                     Error of the fit is 0.0922
#
# ==================================================================================================
# fitting well 1,0 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4492, 2.4780
#
#                                        2 peaks were found:
#                                 CF:  16.43, PW:  0.731, BW: 12.00
#                                 CF:  31.50, PW:  0.665, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9750
#                                     Error of the fit is 0.1036
#
# ==================================================================================================
# fitting well 1,0 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4941, 2.4848
#
#                                        2 peaks were found:
#                                 CF:  20.12, PW:  0.875, BW: 12.00
#                                 CF:  37.45, PW:  0.492, BW:  9.09
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9567
#                                     Error of the fit is 0.1528
#
# ==================================================================================================
# fitting well 1,0 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3344, 2.4321
#
#                                        3 peaks were found:
#                                 CF:  15.97, PW:  0.764, BW: 12.00
#                                 CF:  30.70, PW:  0.778, BW: 12.00
#                                 CF:  40.05, PW:  0.729, BW:  1.01
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9770
#                                     Error of the fit is 0.0963
#
# ==================================================================================================
# fitting well 1,0 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4031, 2.4664
#
#                                        3 peaks were found:
#                                 CF:  16.76, PW:  0.776, BW: 12.00
#                                 CF:  31.85, PW:  0.680, BW: 12.00
#                                 CF:  40.01, PW:  0.605, BW:  1.04
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9748
#                                     Error of the fit is 0.0971
#
# ==================================================================================================
# fitting well 1,0 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.5342, 2.5027
#
#                                        2 peaks were found:
#                                 CF:  21.05, PW:  0.819, BW: 12.00
#                                 CF:  37.45, PW:  0.467, BW:  8.60
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9579
#                                     Error of the fit is 0.1452
#
# ==================================================================================================
# fitting well 1,1 0:100
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.5099, 2.4918
#
#                                        2 peaks were found:
#                                 CF:  15.97, PW:  0.771, BW: 12.00
#                                 CF:  30.91, PW:  0.696, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9729
#                                     Error of the fit is 0.1130
#
# ==================================================================================================
# fitting well 1,1 100:200
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.4894, 2.4661
#
#                                        2 peaks were found:
#                                 CF:  15.68, PW:  0.720, BW: 12.00
#                                 CF:  30.36, PW:  0.699, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9737
#                                     Error of the fit is 0.1094
#
# ==================================================================================================
# fitting well 1,1 200:300
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.5781, 2.4320
#
#                                        1 peaks were found:
#                                 CF:  21.20, PW:  0.891, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9357
#                                     Error of the fit is 0.2102
#
# ==================================================================================================
# fitting well 1,1 300:400
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.6219, 2.4631
#
#                                        1 peaks were found:
#                                 CF:  22.03, PW:  0.921, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9203
#                                     Error of the fit is 0.2356
#
# ==================================================================================================
# fitting well 1,1 400:500
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.3772, 2.4205
#
#                                        2 peaks were found:
#                                 CF:  15.43, PW:  0.810, BW: 12.00
#                                 CF:  30.74, PW:  0.712, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9770
#                                     Error of the fit is 0.1025
#
# ==================================================================================================
# fitting well 1,1 500:600
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
# ==================================================================================================
#
#                                    FOOOF - POWER SPECTRUM MODEL
#
#                         The model was run on the frequency range 1 - 50 Hz
#                                  Frequency Resolution is 0.50 Hz
#
#                             Aperiodic Parameters (offset, exponent):
#                                           3.6059, 2.4584
#
#                                        1 peaks were found:
#                                 CF:  21.90, PW:  0.898, BW: 12.00
#
#                                      Goodness of fit metrics:
#                                     R^2 of model fit is 0.9304
#                                     Error of the fit is 0.2147
#
# ==================================================================================================

# %%
ndsp_wind_thresh(binary_activity, lfp_data, 100)
# Out:
# fitting all 100s active windows per well
# fitting well 1,0 0:100
# fitting well 1,0 100:200
# fitting well 1,0 200:300
# fitting well 1,0 300:400
# fitting well 1,0 400:500
# fitting well 1,0 500:600
# fitting well 1,1 0:100
# fitting well 1,1 100:200
# fitting well 1,1 200:300
# fitting well 1,1 300:400
# fitting well 1,1 400:500
# fitting well 1,1 500:600

# %% [markdown]
# ## Variation of FoooF Parameters

# %%
fm_array = set_fm_array(lfp_data)
# Out:
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.
#
#
# FOOOF WARNING: Lower-bound peak width limit is < or ~= the frequency resolution: 0.50 <= 0.50
# 	Lower bounds below frequency-resolution have no effect (effective lower bound is the frequency resolution).
# 	Too low a limit may lead to overfitting noise as small bandwidth peaks.
# 	We recommend a lower bound of approximately 2x the frequency resolution.

# %%
param_heatmap(fm_array)

# %%
dose_grid = np.array([
    ['eGFP', 'eGFP', 'eGFP'],
    ['CheRiff', 'CheRiff', 'CheRiff']])

# %%
plot_variability(fm_array, dose_grid)
# Out:
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:633: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=values, palette="viridis")
# C:\Users\david\Documents\Voytek Research\psychedelic_organoids\PlateA\A_LFP_analysis_functions.py:633: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=categories, y=values, palette="viridis")

# %%
plot_aperiodic_boxplot(fm_array,  dose_grid)

# %%
 plot_peak_boxplot(fm_array,  dose_grid)
